# %%
import requests
from bs4 import BeautifulSoup   
import webbrowser
import urllib
import re

# %%
page = requests.get("https://ebilet.tcddtasimacilik.gov.tr/view/eybis/tnmGenel/tcddWebContent.jsf?expired=true")
soup = BeautifulSoup(page.content, 'html.parser')
nereden = soup.find(class_="ui-inputfield ui-inputtext ui-widget ui-state-default ui-corner-all ui-autocomplete-input")
gidis_tarihi = soup.find(id='trCalGid_input')
# tonight = forecast_items[0]
# print(tonight.prettify())

# %%
# period = tonight.find(class_='period-name').get_text()
# desc= tonight.find(class_='short-desc').get_text()
# temp = tonight.find(class_='temp temp-high').get_text()

# print(period)
# print(desc)
# print(temp)
# Out:
# Today
# PatchyDrizzle andPatchy Fogthen MostlySunny
# High: 64 °F

# %%
import requests

URL = 'https://ebilet.tcddtasimacilik.gov.tr/view/eybis/tnmGenel/tcddWebContent.jsf'
payload = {
    'neredens': 'Eskisehir',
    'nereye': 'Gebze',
    'trCalGid_input': '24.08.2018'
}

session = requests.session()
r = requests.post(URL, data=payload)
soup = BeautifulSoup(r.content)
print (soup)
# Out:
# <!DOCTYPE HTML>
# <html class="android mobile portrait" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta content="EmulateIE8" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...
