# %%
import pandas as pd
import json   
import matplotlib.pyplot as plt
import csv
from matplotlib import pylab

import plotly as py
import numpy as np

# %%
mcsv = pd.read_csv('USvideos.csv')
oldu = pd.read_csv('oldu.csv')

mjson = open('US_category_id.json')

pjson = json.load(mjson)
json_data = []

with open('C:\\workspace\\US_category_id.json') as json_file:
     json_data = json.load(json_file)

# %%
mylist = mcsv['category_id'].tolist()

# %%
mydict = {}
listID = []
listType = []

# %%
for x in range(43):

    for item in json_data['items'][x]['id'].splitlines():
        print('ID:' + item)
        listID.append(item)
    for item in json_data['items'][x]['snippet']['title'].splitlines():
        print('Type:' + item)
        listType.append(item)
    
    print('-----------*')
    
mydict = dict(zip(listID,listType))
# Out:
# ID:1
# Type:Film & Animation
# -----------*
# ID:2
# Type:Autos & Vehicles
# -----------*
# ID:10
# Type:Music
# -----------*
# ID:15
# Type:Pets & Animals
# -----------*
# ID:17
# Type:Sports
# -----------*
# ID:18
# Type:Short Movies
# -----------*
# ID:19
# Type:Travel & Events
# -----------*
# ID:20
# Type:Gaming
# -----------*
# ID:21
# Type:Videoblogging
# -----------*
# ID:22
# Type:People & Blogs
# -----------*
# ID:23
# Type:Comedy
# -----------*
# ID:24
# Type:Entertainment
# -----------*
# ID:25
# Type:News & Politics
# -----------*
# ID:26
# Type:Howto & Style
# -----------*
# ID:27
# Type:Education
# -----------*
# ID:28
# Type:Science & Technology
# -----------*
# ID:29
# Type:Nonprofits & Activism
# -----------*
# ID:30
# Type:Movies
# -----------*
# ID:31
# Type:Anime/Animation
# -----------*
# ID:32
# Type:Action/Adventure
# -----------*
# ID:33
# Type:Classics
# -----------*
# ID:34
# Type:Comedy
# -----------*
# ID:35
# Type:Documentary
# -----------*
# ID:36
# ...

# %%
newColList = []
for x in range(len(mcsv['category_id'])):

    for key in mydict:
        if mcsv['category_id'][x] == int(key):

            newColList.append(mydict[key])

# %%
mcsv['video_types']= newColList
mcsv.to_csv('C:\\workspace\\oldu.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-feb667a1d97d> in <module>()
# ----> 1 mcsv['video_types']= newColList
#       2 mcsv.to_csv('C:\\workspace\\oldu.csv')
#       3
#
# ~\AppData\Local\conda\conda\envs\env1\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~\AppData\Local\conda\conda\envs\env1\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ...

# %%
for x in range(len(oldu['video_types'])):
    for y in counter:
        if (oldu['video_types'][x] == y  ):
            counter[oldu['video_types'][x]] = oldu['likes'][x]+counter[y]
    

for x in range(len(oldu['video_types'])):
    for y in dictDislikes:
        if (oldu['video_types'][x] == y  ):
            dictDislikes[oldu['video_types'][x]] = oldu['dislikes'][x]+dictDislikes[y]

for x in range(len(oldu['video_types'])):
    for y in dictViews:
        if (oldu['video_types'][x] == y  ):
            dictViews[oldu['video_types'][x]] = oldu['views'][x]+dictViews[y]

# %%
listZero = []
for x in listType:
    listZero.append(0)
counter= dict(zip(listType,listZero))
print(counter)
# Out:
# {'Film & Animation': 0, 'Autos & Vehicles': 0, 'Music': 0, 'Pets & Animals': 0, 'Sports': 0, 'Short Movies': 0, 'Travel & Events': 0, 'Gaming': 0, 'Videoblogging': 0, 'People & Blogs': 0, 'Comedy': 0, 'Entertainment': 0, 'News & Politics': 0, 'Howto & Style': 0, 'Education': 0, 'Science & Technology': 0, 'Nonprofits & Activism': 0, 'Movies': 0, 'Anime/Animation': 0, 'Action/Adventure': 0, 'Classics': 0, 'Documentary': 0, 'Drama': 0, 'Family': 0, 'Foreign': 0, 'Horror': 0, 'Sci-Fi/Fantasy': 0, 'Thriller': 0, 'Shorts': 0, 'Shows': 0, 'Trailers': 0}

# %%
dictDislikes= dict(zip(listType,listZero))
dictViews = dict(zip(listType,listZero))

# %%
data = []
for x in dictLikes:
    data.append([x,int(dictLikes[x]), int(dictDislikes[x]), int(dictViews[x])])

# %%
dataf = pd.DataFrame(data, columns=['Type','Likes','Dislikes','Views'])

dataf = dataf[dataf.Likes != 0]

print(dataf)
# Out:
#                      Type       Likes  Dislikes        Views
# 0        Film & Animation   171658289   6075148   7284156721
# 1        Autos & Vehicles     5298318    243010    520690717
# 2                   Music  1440340921  51179005  40132812168
# 3          Pets & Animals    21056311    527379    764651989
# 4                  Sports    96619285   5017083   4212370360
# 6         Travel & Events     6060349    340427    343557084
# 7                  Gaming    78669834   9157592   2130739179
# 9          People & Blogs   187680797  10187901   4917191726
# 10                 Comedy   216934879   7230391   5117426208
# 11          Entertainment   531582942  42987663  20604388195
# 12        News & Politics    18950444   4180049   1473765704
# 13          Howto & Style   164339460   5472071   4077394972
# 14              Education    50237504   1351972   1180629990
# 15   Science & Technology    84457983   4548402   3487756816
# ...

# %% [markdown]
# ## US YOUTUBE STATS

# %%
# %matplotlib inline
plot1 = dataf.plot(x='Type', y=['Views','Likes','Dislikes'], kind='bar', figsize= (14,10), grid= 1, title='Likes & Dislikes',
                    logy=True, fontsize=15    )
# Out:
# Text(0,0.5,'Amount')

# %%
plot1.set_ylabel('Amount')
plot1 = dataf.plot(x='Type', y=['Likes','Dislikes'], kind='bar', figsize= (14,10), grid= 1, title='Likes & Dislikes',
                    logy=True , fontsize=15      )

# %%
plot2 = dataf.plot(x='Type', y=['Views'], kind='bar', figsize= (14,10),grid= 1 , title= 'Views',logy=True, fontsize=15 )
plot2.set_ylabel('Amount')
# Out:
# Text(0,0.5,'Amount')
